# %%
import npia
import matplotlib.pyplot as plt

# %%
img = npia.Image('PtnanoCenk0.5et_171218_AM.0_00002_1.png',3)

# %%
img.prepare()

# %%
img.show_image(plt.cm.gray)

# %%
img.apply_threshold()

# %%
img.show_image(plt.cm.gray)

# %%
img.apply_gaussian_filter()
# Out:
# C:\Users\Damilola\Anaconda3\envs\ECStutorial\lib\site-packages\mahotas\internal.py:112: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(A.dtype, np.float):

# %%
img.watershed()

# %%
img.show_image(plt.cm.gray)

# %%
img.particle_distances()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-eba6cca11919> in <module>()
# ----> 1 img.particle_distances()
#
# TypeError: 'list' object is not callable
